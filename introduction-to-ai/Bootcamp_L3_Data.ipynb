# %% [markdown]
# # Data

# %% [markdown]
# This notebook is about reading into data. You will learn to:
#
# 1. read a dataset from a CSV file (comma separated values);
# 2. visualise data through plots;
# 3. exploratory data analysis: identify patterns, correlations and trends.

# %% [markdown]
# ## 0. Intro to Datasets

# %% [markdown]
# But what is a dataset? = It is a collection of (nicely-structured) data.
#
# We will firstly learn about **tabular** datasets. Why do you think they are called tabular?
#
# They are called tabular because ... data can be organised in a table.
#
# Each $\color{green}{\text{row}}$ represents a different $\color{green}{\text{sample}}$ (or a data point, or datum 💀).
#
# The $\color{blue}{\text{columns}}$ are for attributes or $\color{blue}{\text{features}}$.
#
# Firstly, let's analyze a simple dataset.

# %%
import pandas as pd

house_dict = {
    "Price": [400000, 150000, 700000, 200000, 600000, 450000, 300000, 500000, 250000, 350000],
    "Squared Meters": [130, 50, 250, 75, 200, 150, 110, 160, 90, 120],
    "Rooms": [4, 2, 7, 3, 6, 5, 4, 5, 3, 4],
    "Bathrooms": [3, 1, 4, 1, 4, 3, 2, 3, 2, 2],
    "Heating Type": ["Central", "Electric", "Central", "Electric", "Central", "Electric", "Central", "Electric", "Central", "Electric"],
    "Parking Availability": ["Available", "Not Available", "Available", "Not Available", "Available", "Not Available", "Available", "Not Available", "Available", "Not Available"],
    "Neighborhood Rating": ["Good", "Average", "Excellent", "Poor", "Good", "Average", "Excellent", "Poor", "Good", "Excellent"],
    "Description": [
        "A cozy 2-bedroom cottage with a charming garden and a fireplace, located in a quiet suburban neighborhood.",
        "A modern 4-bedroom villa featuring a rooftop pool, open-concept living spaces, and panoramic ocean views.",
        "A rustic 3-bedroom cabin surrounded by forest, with a wood-burning stove and a spacious deck for outdoor relaxation.",
        "A luxurious 5-bedroom mansion with marble flooring, a home theater, and a private tennis court in a gated community.",
        "A stylish 1-bedroom apartment in the heart of downtown, boasting floor-to-ceiling windows and a modern kitchen.",
        "A traditional farmhouse with 6 bedrooms, a large barn, and acres of rolling countryside for farming or recreation.",
        "A compact studio loft with industrial-style decor, exposed brick walls, and close proximity to trendy cafes and shops.",
        "A spacious family home with 3 bedrooms, a backyard play area, and a finished basement ideal for a home office or gym.",
        "A beachfront bungalow with 2 bedrooms, direct access to the sand, and a wraparound porch for enjoying sunsets.",
        "A charming 3-bedroom townhouse with a cozy patio, energy-efficient appliances, and a short walk to schools and parks."
    ]
}

house_data = pd.DataFrame(house_dict)

house_data
# Out:
#     Price  Squared Meters  Rooms  Bathrooms Heating Type Parking Availability  \
# 0  400000             130      4          3      Central            Available
# 1  150000              50      2          1     Electric        Not Available
# 2  700000             250      7          4      Central            Available
# 3  200000              75      3          1     Electric        Not Available
# 4  600000             200      6          4      Central            Available
# 5  450000             150      5          3     Electric        Not Available
# 6  300000             110      4          2      Central            Available
# 7  500000             160      5          3     Electric        Not Available
# 8  250000              90      3          2      Central            Available
# 9  350000             120      4          2     Electric        Not Available
#
#   Neighborhood Rating                                        Description
# ...

# %% [markdown]
# Pretty awesome, right? We have a dataset with information about 10 houses.
#
# Each row represents a data point or in this case... an individual house. The first row (with bold letters) is called the **header** and it contains the names of the columns.
#
# There are 7 columns (price, squared meters, rooms, etc.). These are the features.
#
# There are two types of features: **numerical** (as in Rooms, Bathrooms, etc.) or **categorical** (Heating Type, Neighbourhood Rating, Parking Availability).
#
# $\color{red}{ToDo:}$ Answer the following questions about the dataset?
# 1. What is the neighbourhood rating of house 5?
# 2. How much it costs to buy house 3?
# 3. How many rooms does house 8 have?

# %% [markdown]
# ## 1. Read a dataset

# %% [markdown]
# ### Load dataset

# %% [markdown]
# Alrighty, let's focus now and advance to more complicated datasets. Let's deal with a real dataset. To do that, we will use **diabetes.csv**.
#
#
# Pandas module is very helpful and easy to use.. you just provide the CSV filename and it creates a table out of the content.

# %%
filename = "diabetes.csv"

data = pd.read_csv(filename)

# %%
len(data)
# Out:
# 768

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Wow, 768 rows... A lot of rows. Let's check just some of them to understand what we're dealing with.

# %%
data.head(10) # special function that prints only first 5 rows (default is 5, but you can change it)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# Nice, we have 9 columns... all of them being numerical.
#
# Since the dataset is called *diabetes*, the column outcome marks if a patient has diabetes (=1) or not (=0).
#
# Usually, when a data scientist meets a new dataset he asks himself multiple questions about the data to get insights, find patterns or limitations.
#
# Many of them can be answered using a method called **describe()**.

# %% [markdown]
# ### Answer questions about the dataset

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Questions:
#
# 1. Is there any missing information? Row count answer this question. Since for all columns the count values are equal to number of rows, we're good. No missing info.
#
# 2. What are the limits? max and min provides that info for each column.
#
# 3. What are the mean values for each column?

# %% [markdown]
# $\color{red}{ToDo:}$ Answer:
# 1. What is the mean of patients' ages?
# 2. What is the maximum insulin value?
# 3. What are the maximum number of pregnancies?

# %% [markdown]
# EXTRA: What is std and 25%, 50%, 75%?

# %% [markdown]
# Ok, seeing a lot of numbers is pretty boring. Let's *view* the data. In order to that we will generate some plots using a module called matplotlib.

# %% [markdown]
# ### 1. How many people have diabetes? - Bar Plot

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import matplotlib.pyplot as plt

# we have to access only the column with outcome -> data['Outcome']
# to count we will use the method .value_counts()
counts = data['Outcome'].value_counts()
counts
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# As it can be seen, counts variable has two columns: first is the unique outcomes (only 0 and 1) and then is the count for each of them.

# %%
counts.index
# Out:
# Index([0, 1], dtype='int64', name='Outcome')

# %%
counts.values
# Out:
# array([500, 268])

# %%
plt.figure(figsize=(6, 4)) # dimensions of the figure

plt.bar(counts.index, counts.values, color=['red', 'blue'])

plt.xlabel('Outcome')
plt.ylabel('Count')

plt.title('Count of Diabetes Outcomes')
plt.xticks(ticks=[0, 1], labels=['No Diabetes', 'Diabetes']) # We associate labels to the classes

plt.show()

# %% [markdown]
# This is a bar plot because it contains bars. It is mainly used when we deal with categories and we want to compare their counts.

# %% [markdown]
# **TRICKY:** Ok, you might ask yourself... oh wait a second, what categories because this is numerical data not categorical. Well, although they are numbers 0 and 1, they mimic categories. So, categories are not just text, they can be numbers as well. If a feature has only numbers, but they represent categories or groups that is a categorical feature.

# %% [markdown]
# An easier example would be:

# %%
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 8]

plt.bar(categories, values, color=['#FFFF00', 'red', 'blue', 'black'])
plt.title("Bar Plot Easy")
plt.xlabel("Category")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ### 2. What is the percentage of people with diabetes? - Pie Plot

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x: 'ArrayLike', explode: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, colors: 'ColorType | Sequence[ColorType] | None' = None, autopct: 'str | Callable[[float], str] | None' = None, pctdistance: 'float' = 0.6, shadow: 'bool' = False, labeldistance: 'float | None' = 1.1, startangle: 'float' = 0, radius: 'float' = 1, counterclock: 'bool' = True, wedgeprops: 'dict[str, Any] | None' = None, textprops: 'dict[str, Any] | None' = None, center: 'tuple[float, float]' = (0, 0), frame: 'bool' = False, rotatelabels: 'bool' = False, *, normalize: 'bool' = True, hatch: 'str | Sequence[str] | None' = None, data=None) -> 'tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]'
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
# ...

# %%
[500, 355]
[500 / (355 + 500), 355 / (355 + 500)]

# %%
plt.figure(figsize=(5, 4))
plt.pie(counts.values, labels=['sanatos', 'bolnav'], autopct='%1.2f%%')
plt.title("Pie Chart with Diabetes Outcome")
plt.show()

# %% [markdown]
# And for the baby dataset:

# %%
plt.pie(values, labels=categories, autopct='%1.1f%%')
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# ### 3. What are the ages of the patients? - Histogram

# %%
plt.hist(data['Glucose'], color='purple')
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Basically, they are multiple bar plots put near each other. 30 bars (bins=30) each with its frequency (or count).
#
# What information we can infer from the plot? Try several values for the bins. Can you understand how the bins value works?

# %% [markdown]
# $\color{red}{ToDo:}$ Plot 2 or 3 more histograms based on other columns. Explore how the data is **distributed** along its possible values.

# %% [markdown]
# Alright, we got an idea about how to look in the data... but let's properly see the data. Now, the magic begins.

# %% [markdown]
# ## 2. Understanding data as points in space

# %% [markdown]
# ### Data points

# %% [markdown]
# In order to see the data we'll have to understand the view it from a geometric perspective.
#
# Let's firstly use the basic dataset with houses and we will then come back to the houses. For the moment, we need only the numerical values, so we are going to ignore the columns that are text.

# %%
house_data
# Out:
#     Price  Squared Meters  Rooms  Bathrooms Heating Type Parking Availability  \
# 0  400000             130      4          3      Central            Available
# 1  150000              50      2          1     Electric        Not Available
# 2  700000             250      7          4      Central            Available
# 3  200000              75      3          1     Electric        Not Available
# 4  600000             200      6          4      Central            Available
# 5  450000             150      5          3     Electric        Not Available
# 6  300000             110      4          2      Central            Available
# 7  500000             160      5          3     Electric        Not Available
# 8  250000              90      3          2      Central            Available
# 9  350000             120      4          2     Electric        Not Available
#
#   Neighborhood Rating
# 0                Good
# 1             Average
# 2           Excellent
# ...

# %% [markdown]
# We will now select two columns: Squared Meters and Price and plot them. Each house will be a point on the graph.
#
# On the **horizontal axis**, we will represent the **Squared Meters** and on the *vertical axis* we will have the *Price*. Let's see!

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

icon_path = 'house_icon.png'
icon = mpimg.imread(icon_path)

def add_icon(ax, x, y, icon, zoom=0.04):
    imagebox = OffsetImage(icon, zoom=zoom)
    ab = AnnotationBbox(imagebox, (x, y), frameon=False)
    ax.add_artist(ab)

fig, ax = plt.subplots()

# this is the command for plotting the points: the first argument is an array with values on horizontal axis, the second arg is an array with values on vertical axis
ax.scatter(house_data['Squared Meters'], house_data['Price'], color='blue')

# this is for plotting number above the points
for i in range(len(house_data)):
    plt.annotate(i, (house_data['Squared Meters'][i], house_data['Price'][i]), textcoords="offset points", xytext=(0,12), ha='center')

for i in range(len(house_data)):
    add_icon(ax, house_data['Squared Meters'][i], house_data['Price'][i], icon)

plt.title("Houses (Price vs Squared Meters)")
plt.xlim((20, 300))
plt.ylim((90000, 750000))
plt.grid()
plt.xlabel("Squared Meters")
plt.ylabel("Price (in $)")

plt.show()

# %%
house_data
# Out:
#     Price  Squared Meters  Rooms  Bathrooms Heating Type Parking Availability  \
# 0  400000             130      4          3      Central            Available
# 1  150000              50      2          1     Electric        Not Available
# 2  700000             250      7          4      Central            Available
# 3  200000              75      3          1     Electric        Not Available
# 4  600000             200      6          4      Central            Available
# 5  450000             150      5          3     Electric        Not Available
# 6  300000             110      4          2      Central            Available
# 7  500000             160      5          3     Electric        Not Available
# 8  250000              90      3          2      Central            Available
# 9  350000             120      4          2     Electric        Not Available
#
#   Neighborhood Rating
# 0                Good
# 1             Average
# 2           Excellent
# ...

# %% [markdown]
# Alright, each blue point corresponds to a sample. More precisely, each point is a house. Furthermore, by plotting the points we can see a trend. What can we visually infer from the plot?

# %% [markdown]
# Exactly, the bigger the space, the higher the price.
#
# This is a 2-dimensional space so it depicts the relationship between two features. Let's take it to the next level and also include the rooms. Now we're going to a 3-dimensional space. For that we will use plotly which is used for **interactive** plots. These are cooler... you can play with the space and see the points from multiple angles.
#
# HINT: Try hovering on the points.

# %%
import plotly.express as px

fig = px.scatter_3d(house_data, x='Squared Meters', y='Rooms', z='Price', title="3D Scatter Plot")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Can you identify another trend in here?

# %% [markdown]
# **TRICKY:** Ok, let's use all the features to plot a house. But there are 4 numerical columns, what can we do? How can we plot a 4-dimensional space... That is difficult. As humans we only perceive 3D. There are some tricks like making the points spheres where the radius is equal to the 4th feature, but it really makes the process of seeing into the data more difficult.
#
# Data scientists work with hundreds and maybe thousands of dimensions. It is very difficult to plot a point in a n-dimensional space.
#
# **REMEMBER:** At the end of the day, the samples are just points in n-dimensional spaces where n is the number of features. Each dimension is asociated with a specific feature or column.
#
# In our case, the houses are just 4-dimensional points in space, but we are going to explore data with tens, hundreds or even thousands features.

# %% [markdown]
# ### Example - Distance

# %% [markdown]
# How important is to view the data and make plots? Hmm... Extremely important.
#
# Let's imagine we have a dataset with some samples that have only two features. The samples are humans and the features are two genes. They are quantified in some biological manner.

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_features=2, center_box=(20, 40), random_state=42)

plt.xlabel("Gene 1")
plt.ylabel("Gene 2")

plt.scatter(X[:,0], X[:,1]) # wait for a moment and take this for granted, please

# %% [markdown]
# These are the points. Wow. Human's brain immediately recognized three groups or categories or **clusters**. Each of these three clusters might have distinct fenotypes (or traits such as having blue eyes or hazel or brown). But what is the key information that need to be provided to the computer to make it *see* there are three groups?

# %% [markdown]
# Distance between points in space is crucial. We instantly perceived the points and compute the distances. But how to compute them using computers?
#
# We can use **Euclidean distances** between two points to check if they are close or far.
#
# The closer they are, the more similar they are whereas when they are far from each other, it means they are different.
#
# Data as points on a graph is neat.

# %% [markdown]
# ## Extra Example

# %% [markdown]
# So I know what you are thinking right now. Yeah yeah, plotting data points are nice, but what about the text features? Is that a limitation? We will not go into that right now because it is far too complicated, but take a quick look at the next graph and enjoy your wow moment.

# %% [markdown]
# ![Alt text](https://www.mathworks.com/help/examples/textanalytics/win64/VisualizeWordEmbeddingsUsingTextScatterPlotsExample_02.png)
#
# Credits: https://www.mathworks.com/help/textanalytics/ug/visualize-word-embedding-using-text-scatter-plot.html

# %% [markdown]
# ## 3. Data as vectors

# %%
house_data.head()
# Out:
#     Price  Squared Meters  Rooms  Bathrooms Heating Type Parking Availability  \
# 0  400000             130      4          3      Central            Available
# 1  150000              50      2          1     Electric        Not Available
# 2  700000             250      7          4      Central            Available
# 3  200000              75      3          1     Electric        Not Available
# 4  600000             200      6          4      Central            Available
#
#   Neighborhood Rating
# 0                Good
# 1             Average
# 2           Excellent
# 3                Poor
# 4                Good

# %% [markdown]
# Previously, we extracted just a column using a similar syntax to dicts. Let's extract a row which represents a single sample.

# %%
house0_features = house_data.iloc[0] # iloc means Integer LOCation
house0_features
# Out:
# Price                      400000
# Squared Meters                130
# Rooms                           4
# Bathrooms                       3
# Heating Type              Central
# Parking Availability    Available
# Neighborhood Rating          Good
# Name: 0, dtype: object

# %% [markdown]
# Let's remove the header from the previous view and focus only on the numerical attributes.

# %%
list(house0_features[:4])
# Out:
# [400000, 130, 4, 3]

# %% [markdown]
# A single sample can be described as a **list** | **vector** | **array** of its features.

# %% [markdown]
# Vector is a term that is use in multiple fields such as maths, physics and computer science. At its core, it refers to an entity described by a list of numbers.

# %% [markdown]
# In computer science, we use the term vector to denote a fixed-length sequence. Usually, the order in a vector is very important. Look at the above example and imagine changing the last element with the first. It will mean the price is 3$ and there are 400000 rooms. That will be a crucial mistake. Regarding the length, we also refer to it as size or dimension.

# %% [markdown]
# In maths and physics, vectors are important concepts as well because they have *magnitude* and *direction* 😟.
#
# Imagine you are passing a ball to your teammate. You have to pass it with a certain power (magnitude) and in a certain direction. Now imagine you are on a field. You are point A (the red one) and he is point B (the blue one). The ball is going from A to B and it goes for a certain distance. The vector will show the path of the ball having also an arrow on the head to emphasize the direction.

# %%
# the code is not important to understand -> just for the visualization

import matplotlib.pyplot as plt
import numpy as np

point_A = np.array([2, 2])
point_B = np.array([6, 8])

plt.figure(figsize=(6, 6))
plt.quiver(point_A[0], point_A[1],
           point_B[0] - point_A[0], point_B[1] - point_A[1],
           angles='xy', scale_units='xy', scale=1, color='purple', label="Vector AB")

# Mark points A and B
plt.scatter(*point_A, color='red', label="Point A (2,2)", zorder=5)
plt.scatter(*point_B, color='blue', label="Point B (6,8)", zorder=5)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Vector from A to B")
plt.legend()
plt.grid(True)
plt.axis('equal')

plt.xlim((-5, 10))
plt.ylim((-5, 10))
plt.show()

# %% [markdown]
# Magnitude and direction are present explicitly in computer science mostly in games or graphics.

# %% [markdown]
# Alright, that's enough... back to our data!
#
# Are these geometric vectors really important to us? Are magnitude and direction relevant to us? Why don't we just treat the data points as simple points and that's it?
#
# **ANSWER:** No, for the moment magnitude and direction is not relevant to us. Despite this, **in some cases** we will treat our data points as geometric vectors because both *geometric* vectors and our *vectors* (lists of numbers) have two properties that behave exactly the same: **addition** and **multiplication**.

# %% [markdown]
# Imagine you own house0 and then you buy house1. For more intuition, imagine that both of them are part of a duplex. Now you own both the houses - you own the entire duplex. If you have to describe your entire duplex as a new single vector including price, rooms, squared meters, bathrooms, how would you do that?

# %%
house_data.head(1)

# %%
house0 = list(house_data.iloc[0][:4])
house1 = list(house_data.iloc[1][:4])

house0, house1
# Out:
# ([400000, 130, 4, 3], [150000, 50, 2, 1])

# %% [markdown]
# Exactly, you sum component by component.
#
# Your duplex is represented by a new vector computed as a sum of the two houses.

# %%
duplex = house0 + house1
duplex
# Out:
# [400000, 130, 4, 3, 150000, 50, 2, 1]

# %% [markdown]
# Oh my god. That's bad. There should be another way.

# %%
# zip(house0, house1) => [(400000, 150000), (130, 50), (4, 2), (3, 1)]

# %%
duplex = []
for x, y in zip(house0, house1):
    duplex.append(x + y)
duplex
# Out:
# [550000, 180, 6, 4]

# %% [markdown]
# Ok, now it looks good. My duplex is worth 55000, it has a total of 180 sq m, 6 rooms and 4 bathrooms. Cool!
#
# But the code is just too much for a simple sum between two vectors. Here is where numpy saves the day. Numpy is a very efficient library designed for this vectors.

# %%
import numpy as np

house0 = np.array(house_data.iloc[0][:4], dtype=int) # create an array - but a special one a numpy array with ints
house1 = np.array(house_data.iloc[1][:4], dtype=int)

house0, house1
# Out:
# (array([400000,    130,      4,      3]),
#  array([150000,     50,      2,      1]))

# %%
# [1, 2, 3, 4]
# array([1, 2, 3, 4]) # un pic mai mult mai inteligent si mai eficient

# %% [markdown]
# We can recognize it because it has a specific mark: array([...]) instead of simply [...].

# %%
duplex = house0 + house1
duplex
# Out:
# array([550000,    180,      6,      4])

# %% [markdown]
# Ok. That's much better.

# %% [markdown]
# Alright, now imagine you buy 4 houses in a fourplex, all of them similar to house2. How you will describe now your entire fourplex?

# %% [markdown]
# Exactly, you will multiply by 4 on each column.

# %%
house2 = list(house_data.iloc[2][:4])

# v = [1, 2, 3]
# 3 * v = [3, 6, 9]

fourplex = 4 * house2
fourplex
# Out:
# [700000, 250, 7, 4, 700000, 250, 7, 4, 700000, 250, 7, 4, 700000, 250, 7, 4]

# %% [markdown]
# Ok, that's bad. Let's try again with numpy.

# %%
house2 = np.array(house_data.iloc[2][:4], dtype=int)

fourplex = 4 * house2
fourplex
# Out:
# array([2800000,    1000,      28,      16])

# %% [markdown]
# Ok, better.

# %% [markdown]
# **CONCLUSION:** Geometric vectors have this exact same properties. When you add two vectors, you add component by component.
# When you multiply a vector with a scalar, you multiply each component by that scalar.

# %% [markdown]
# **TRICKY Q:** A vector was depicted above, but in order to draw it we needed two 2D points. Wait a minute... we associated just a single sample to a vector. Isn't that controversial?

# %% [markdown]
# 3Blue1Brown

# %% [markdown]
# $\color{red}{ToDo:}$ Watch:
# 1.   https://www.youtube.com/watch?v=fNk_zzaMoSs&t=191s
# 2.   https://www.youtube.com/watch?v=ml4NSzCQobk
